# %%
import requests
from config import YOUTUBE_API_KEY

# %%
CHANNEL_ID = "UCsXVk37bltHxD1rDPwtNM8Q"
pageToken = ""
url = "https://www.googleapis.com/youtube/v3/search?key="+YOUTUBE_API_KEY+"&channelId="+CHANNEL_ID+"&part=snippet,id&order=date&maxResults=1000"+pageToken

# %%
print(url)
# Out:
# https://www.googleapis.com/youtube/v3/search?key=AIzaSyAjul0ki9SFfI9f4cTApU0E0RLM-qaXRQE&channelId=UCsXVk37bltHxD1rDPwtNM8Q&part=snippet,id&order=date&maxResults=1000

# %%
response = requests.get(url).json()

# %%
response
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': 'TdmN78t9qFZ-0m8B3pTn4DCZgTg',
#  'nextPageToken': 'CDIQAA',
#  'regionCode': 'TR',
#  'pageInfo': {'totalResults': 227, 'resultsPerPage': 50},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': '4qM-Wu3_5FnOXMt2X4yGf4FQTjw',
#    'id': {'kind': 'youtube#video', 'videoId': 'nGggU-Cxhv0'},
#    'snippet': {'publishedAt': '2023-12-12T15:00:01Z',
#     'channelId': 'UCsXVk37bltHxD1rDPwtNM8Q',
#     'title': 'Your Tattoo is INSIDE Your Immune System. Literally',
#     'description': 'Go to https://brilliant.org/nutshell/ to dive deeper into these topics and more with a free 30-day trial + 20% off for the first 200 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/nGggU-Cxhv0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/nGggU-Cxhv0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/nGggU-Cxhv0/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kurzgesagt – In a Nutshell',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-12-12T15:00:01Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'so7fWeXjNhjCZXTiq86L1_eGZ68',
#    'id': {'kind': 'youtube#video', 'videoId': 'HR2C_7G_yRQ'},
#    'snippet': {'publishedAt': '2023-12-08T15:00:01Z',
#     'channelId': 'UCsXVk37bltHxD1rDPwtNM8Q',
#     'title': 'How To Destroy The Universe',
#     'description': 'LAST CHANCE ✨ Order your 12024 Cosmic Creations Calendar (our most spectacular yet!) to receive it in time for the holidays: ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/HR2C_7G_yRQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/HR2C_7G_yRQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/HR2C_7G_yRQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kurzgesagt – In a Nutshell',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-12-08T15:00:01Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'IPgQBhHkl9WS720v07Zr6CsvTxw',
#    'id': {'kind': 'youtube#video', 'videoId': 'yDMZJ7LgrGY'},
#    'snippet': {'publishedAt': '2023-12-05T16:30:09Z',
#     'channelId': 'UCsXVk37bltHxD1rDPwtNM8Q',
#     'title': 'The Moment Kurzgesagt Changed Forever',
#     'description': 'LAST CHANCE ✨ Order your 12024 Cosmic Creations Calendar (our most spectacular yet!) to receive it in time for the holidays: ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/yDMZJ7LgrGY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/yDMZJ7LgrGY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/yDMZJ7LgrGY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kurzgesagt – In a Nutshell',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-12-05T16:30:09Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'ejYZfI_z31BqPgGAZxzR2cmhTsM',
#    'id': {'kind': 'youtube#video', 'videoId': 'fuFlMtZmvY0'},
#    'snippet': {'publishedAt': '2023-11-29T15:00:43Z',
#     'channelId': 'UCsXVk37bltHxD1rDPwtNM8Q',
#     'title': 'The Internet is Worse Than Ever – Now What?',
#     'description': "Go to https://ground.news/nutshell to get 30% off unlimited access to Ground News - a website and app that gathers the world's ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/fuFlMtZmvY0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/fuFlMtZmvY0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/fuFlMtZmvY0/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kurzgesagt – In a Nutshell',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-11-29T15:00:43Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'LMETzNdPuMXuEdwVfCSYZuMENW4',
#    'id': {'kind': 'youtube#video', 'videoId': 'FgnjdW-x7mQ'},
#    'snippet': {'publishedAt': '2023-11-21T15:00:01Z',
#     'channelId': 'UCsXVk37bltHxD1rDPwtNM8Q',
#     'title': 'The Last Thing To Ever Happen In The Universe',
#     'description': 'Get 50% off your first month of KiwiCo at https://www.kiwico.com/kurzgesagt with code KURZGESAGT. This video was sponsored ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/FgnjdW-x7mQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/FgnjdW-x7mQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/FgnjdW-x7mQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kurzgesagt – In a Nutshell',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-11-21T15:00:01Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'oSUiXRk_OE26E_ywudixAAHWBvk',
#    'id': {'kind': 'youtube#video', 'videoId': 'tybKnGZRwcU'},
#    'snippet': {'publishedAt': '2023-11-15T15:00:01Z',
#     'channelId': 'UCsXVk37bltHxD1rDPwtNM8Q',
#     'title': 'How to Win an Interstellar War',
#     'description': 'Join the Galactic Club: your cozy corner in the vast universe ✨ https://shop.kgs.link/galactic-club Get everything you need to fit ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/tybKnGZRwcU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/tybKnGZRwcU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/tybKnGZRwcU/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kurzgesagt – In a Nutshell',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-11-15T15:00:01Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'Juj_lfUR39qqnbn9XMSHQfPwIvc',
#    'id': {'kind': 'youtube#video', 'videoId': 'S7TUe5w6RHo'},
#    'snippet': {'publishedAt': '2023-11-10T16:15:06Z',
#     'channelId': 'UCsXVk37bltHxD1rDPwtNM8Q',
#     'title': '4.5 Billion Years in 1 Hour',
#     'description': 'Learn more about how complex life evolved with our new, elaborately detailed Timeline of Evolution Poster. Available only on the ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/S7TUe5w6RHo/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/S7TUe5w6RHo/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/S7TUe5w6RHo/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kurzgesagt – In a Nutshell',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-11-10T16:15:06Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '-1S5YPexRx9biDidl-wwKil3m9s',
#    'id': {'kind': 'youtube#video', 'videoId': 'Qtmrp_4BKRQ'},
#    'snippet': {'publishedAt': '2023-10-17T14:04:14Z',
#     'channelId': 'UCsXVk37bltHxD1rDPwtNM8Q',
#     'title': 'A Glimpse Into Our Future',
#     'description': 'WORLDWIDE SHIPPING AVAILABLE ✨ The 12024 Human Era Calendar has landed! https://shop.kgs.link/12-024 Join us on an ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Qtmrp_4BKRQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Qtmrp_4BKRQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Qtmrp_4BKRQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kurzgesagt – In a Nutshell',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-10-17T14:04:14Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'aqA3VYUEG2OM00phnINnAzrz6dM',
#    'id': {'kind': 'youtube#video', 'videoId': 'JOiGEI9pQBs'},
#    'snippet': {'publishedAt': '2023-10-10T14:00:02Z',
#     'channelId': 'UCsXVk37bltHxD1rDPwtNM8Q',
#     'title': 'Ancient Life as Old as the Universe',
#     'description': 'WORLDWIDE SHIPPING AVAILABLE ✨ The 12024 Human Era Calendar has landed! https://shop.kgs.link/12024 Join us on an ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/JOiGEI9pQBs/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/JOiGEI9pQBs/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/JOiGEI9pQBs/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kurzgesagt – In a Nutshell',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-10-10T14:00:02Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'z--fvL5Xp8Nx9uJ--wbzaCwWE3M',
#    'id': {'kind': 'youtube#video', 'videoId': 'LBudghsdByQ'},
#    'snippet': {'publishedAt': '2023-10-04T14:00:02Z',
#     'channelId': 'UCsXVk37bltHxD1rDPwtNM8Q',
#     'title': 'Why Korea is Dying Out',
#     'description': 'Go to https://brilliant.org/nutshell/ to dive deeper into these topics and more with a free 30-day trial + 20% off for the first 200 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/LBudghsdByQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/LBudghsdByQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/LBudghsdByQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kurzgesagt – In a Nutshell',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-10-04T14:00:02Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'aZ4_TSGok8BSnTJKzXBLOetmTJQ',
#    'id': {'kind': 'youtube#video', 'videoId': '4Stzj2_Rlo4'},
#    'snippet': {'publishedAt': '2023-09-12T14:00:06Z',
#     'channelId': 'UCsXVk37bltHxD1rDPwtNM8Q',
#     'title': 'We Did The Math - You Are Dead!',
#     'description': 'To get started planning a fulfilling career that does a lot of good, go to https://80000hours.org/kurzgesagt for your free career guide ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/4Stzj2_Rlo4/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/4Stzj2_Rlo4/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/4Stzj2_Rlo4/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kurzgesagt – In a Nutshell',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-09-12T14:00:06Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'UsaSF4Df-zWPWE2Kc8vAOcdeckI',
#    'id': {'kind': 'youtube#video', 'videoId': 'wmP3MBjsx20'},
#    'snippet': {'publishedAt': '2023-08-22T14:00:08Z',
#     'channelId': 'UCsXVk37bltHxD1rDPwtNM8Q',
#     'title': 'How A Nuclear War Will Start - Minute by Minute',
#     'description': 'This video was made possible through a grant by Open Philanthropy. Sources & further reading: ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/wmP3MBjsx20/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/wmP3MBjsx20/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/wmP3MBjsx20/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kurzgesagt – In a Nutshell',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-08-22T14:00:08Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'Rr-gqfLLesmzYonxFfyMqk7Ou2g',
#    'id': {'kind': 'youtube#video', 'videoId': 'cFslUSyfZPc'},
#    'snippet': {'publishedAt': '2023-08-16T13:59:54Z',
#     'channelId': 'UCsXVk37bltHxD1rDPwtNM8Q',
#     'title': 'What Happens If You Destroy A Black Hole?',
#     'description': "Go 'beyond the nutshell' at https://brilliant.org/nutshell/ and dive deeper into these topics and more with a free 30-day trial!",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/cFslUSyfZPc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/cFslUSyfZPc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/cFslUSyfZPc/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kurzgesagt – In a Nutshell',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-08-16T13:59:54Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'OtOWTvqBlRXMY3Dspyd1KZ04wik',
#    'id': {'kind': 'youtube#video', 'videoId': 'Kr57ax0OWMk'},
#    'snippet': {'publishedAt': '2023-08-08T13:59:49Z',
#     'channelId': 'UCsXVk37bltHxD1rDPwtNM8Q',
#     'title': 'The (Second) Deadliest Virus',
#     'description': 'Sources & further reading: https://sites.google.com/view/sources-smallpox/ This video was made possible through a grant by ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Kr57ax0OWMk/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Kr57ax0OWMk/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Kr57ax0OWMk/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kurzgesagt – In a Nutshell',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-08-08T13:59:49Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'K3HIx6eQ0V7XIlqmps3qdbMxUUk',
#    'id': {'kind': 'youtube#video', 'videoId': '28T91fgkpkA'},
#    'snippet': {'publishedAt': '2023-07-27T14:03:48Z',
#     'channelId': 'UCsXVk37bltHxD1rDPwtNM8Q',
#     'title': 'How Many Moons Could Earth Handle? #kurzgesagt #shorts',
#     'description': 'A beautiful night sky, but it comes with wild tides. Do you accept? And how many moons would you choose? #kurzgesagt ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/28T91fgkpkA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/28T91fgkpkA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/28T91fgkpkA/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kurzgesagt – In a Nutshell',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-07-27T14:03:48Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '2xqZ2EVnp3WxJfk-DGGBRn8p3zk',
#    'id': {'kind': 'youtube#video', 'videoId': '4TlyzKBm5yw'},
#    'snippet': {'publishedAt': '2023-07-20T14:00:03Z',
#     'channelId': 'UCsXVk37bltHxD1rDPwtNM8Q',
#     'title': 'What If You’re in Space without a Spacesuit? #kurzgesagt #shorts',
#     'description': 'How horrible of a scenario do you want to be? Being in Space without a spacesuit: yes. #kurzgesagt #inanutshell #universe ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/4TlyzKBm5yw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/4TlyzKBm5yw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/4TlyzKBm5yw/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kurzgesagt – In a Nutshell',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-07-20T14:00:03Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'TI9SRTZT2U8a6iKcMsX0aBMeedw',
#    'id': {'kind': 'youtube#video', 'videoId': 'kblSnj0p6bE'},
#    'snippet': {'publishedAt': '2023-07-13T14:00:34Z',
#     'channelId': 'UCsXVk37bltHxD1rDPwtNM8Q',
#     'title': 'What Happens if Earth Suddenly Stops Rotating? #kurzgesagt #shorts',
#     'description': "You don't even realize how fast Earth rotates, unless you pause its rotation... #inanutshell #kurzgesagt ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/kblSnj0p6bE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/kblSnj0p6bE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/kblSnj0p6bE/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kurzgesagt – In a Nutshell',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-07-13T14:00:34Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'mMx0MN19iB36BkLPz26E3jabADU',
#    'id': {'kind': 'youtube#video', 'videoId': 'FPKRFw2jrnU'},
#    'snippet': {'publishedAt': '2023-07-06T14:00:12Z',
#     'channelId': 'UCsXVk37bltHxD1rDPwtNM8Q',
#     'title': 'Earth&#39;s Hidden Gem: The Astonishing Diversity of Fauna and Flora #shorts #kurzgesagt',
#     'description': 'So far only 17% of all species estimated to live on Earth have been categorized, out of the estimated 8.7 million! #kurzgesagt ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/FPKRFw2jrnU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/FPKRFw2jrnU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/FPKRFw2jrnU/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kurzgesagt – In a Nutshell',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-07-06T14:00:12Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'KQ-gwJrsxUofqDosPDJa934mcTM',
#    'id': {'kind': 'youtube#video', 'videoId': '9FppammO1zk'},
#    'snippet': {'publishedAt': '2023-07-02T13:00:42Z',
#     'channelId': 'UCsXVk37bltHxD1rDPwtNM8Q',
#     'title': 'The Most Dangerous Weapon Is Not Nuclear',
#     'description': 'Sources & further reading: https://sites.google.com/view/sources-biorisk This video was made possible through a grant by Open ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/9FppammO1zk/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/9FppammO1zk/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/9FppammO1zk/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kurzgesagt – In a Nutshell',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-07-02T13:00:42Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'mlQ1xQIIH2gtx6YL5XhghZoJrC8',
#    'id': {'kind': 'youtube#video', 'videoId': '8Ey3_9N089k'},
#    'snippet': {'publishedAt': '2023-07-02T13:00:05Z',
#     'channelId': 'UCsXVk37bltHxD1rDPwtNM8Q',
#     'title': 'The Next Atomic Bomb Is Made of DNA #kurzgesagt #shorts',
#     'description': 'A breathtaking scientific revolution is taking place – biotechnology has been progressing at incredible speed, giving us the tools to ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/8Ey3_9N089k/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/8Ey3_9N089k/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/8Ey3_9N089k/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kurzgesagt – In a Nutshell',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-07-02T13:00:05Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'o3nHKzBNhGR-reui6B_LWukBgIo',
#    'id': {'kind': 'youtube#video', 'videoId': '_arb8Fu3LXo'},
#    'snippet': {'publishedAt': '2023-06-29T14:00:31Z',
#     'channelId': 'UCsXVk37bltHxD1rDPwtNM8Q',
#     'title': 'Are Your Friends More Popular than You? #shorts #kurzgesagt',
#     'description': 'Remember, while playing with numbers is fun, the real value of your friendships lies within the quality of the friendships you have, ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/_arb8Fu3LXo/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/_arb8Fu3LXo/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/_arb8Fu3LXo/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kurzgesagt – In a Nutshell',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-06-29T14:00:31Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'bTfIAWJmo_qVr-rESpD3LEnvjPw',
#    'id': {'kind': 'youtube#video', 'videoId': 'XFM4tCakAXY'},
#    'snippet': {'publishedAt': '2023-06-22T14:00:21Z',
#     'channelId': 'UCsXVk37bltHxD1rDPwtNM8Q',
#     'title': 'Let&#39;s Make Earth Twice as Large! #shorts #kurzgesagt',
#     'description': "Good thing Earth is not twice as large, because if an apple would fall on a person's head it would give them serious head injuries ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/XFM4tCakAXY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/XFM4tCakAXY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/XFM4tCakAXY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kurzgesagt – In a Nutshell',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-06-22T14:00:21Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'RYhRU8CkSquBAuO31tcPn9Xjfs4',
#    'id': {'kind': 'youtube#video', 'videoId': 'uoJwt9l-XhQ'},
#    'snippet': {'publishedAt': '2023-06-18T13:00:41Z',
#     'channelId': 'UCsXVk37bltHxD1rDPwtNM8Q',
#     'title': 'The Reason Why Cancer is so Hard to Beat',
#     'description': 'Sources & further reading: https://sites.google.com/view/sources-cancer-city/ This video was partially financed by Gates Ventures.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/uoJwt9l-XhQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/uoJwt9l-XhQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/uoJwt9l-XhQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kurzgesagt – In a Nutshell',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-06-18T13:00:41Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'tExCVcxGjuJ9IcSZ7eDAf9bLuKk',
#    'id': {'kind': 'youtube#video', 'videoId': 'BNvL_uZhTsY'},
#    'snippet': {'publishedAt': '2023-06-15T14:06:52Z',
#     'channelId': 'UCsXVk37bltHxD1rDPwtNM8Q',
#     'title': 'Why Does Humanity Exist NOW? #shorts #kurzgesagt',
#     'description': 'In chronically online language, humans might have joined the cosmic chat much later then the universe was born, but in reality, ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/BNvL_uZhTsY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/BNvL_uZhTsY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/BNvL_uZhTsY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kurzgesagt – In a Nutshell',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-06-15T14:06:52Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '0i-Sglnjp5L7W9Q_0cgkonAgix8',
#    'id': {'kind': 'youtube#video', 'videoId': 'V4Z8EdiJxgk'},
#    'snippet': {'publishedAt': '2023-06-11T12:59:39Z',
#     'channelId': 'UCsXVk37bltHxD1rDPwtNM8Q',
#     'title': 'The Black Hole That Kills Galaxies - Quasars',
#     'description': "Go 'beyond the nutshell' at https://brilliant.org/nutshell/ and dive deeper into these topics and more with a free 30-day trial!",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/V4Z8EdiJxgk/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/V4Z8EdiJxgk/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/V4Z8EdiJxgk/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kurzgesagt – In a Nutshell',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-06-11T12:59:39Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'GJIudD5Ks2nJOjffnp8yNMysNfY',
#    'id': {'kind': 'youtube#video', 'videoId': 'RzwaiFvyN6s'},
#    'snippet': {'publishedAt': '2023-06-08T14:00:16Z',
#     'channelId': 'UCsXVk37bltHxD1rDPwtNM8Q',
#     'title': 'How do Lasers Work? #shorts #kurzgesagt',
#     'description': 'Have you ever wondered how lasers work? Well, we did! #inanutshell #kurzgesagt #kurzgesagt_inanutshell #youtubelearning ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/RzwaiFvyN6s/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/RzwaiFvyN6s/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/RzwaiFvyN6s/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kurzgesagt – In a Nutshell',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-06-08T14:00:16Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'uvFU0F2Zq06og7NiwJHujmdJjqA',
#    'id': {'kind': 'youtube#video', 'videoId': 'LNv4y3wPQA0'},
#    'snippet': {'publishedAt': '2023-06-01T14:00:11Z',
#     'channelId': 'UCsXVk37bltHxD1rDPwtNM8Q',
#     'title': 'Earth as a Cube – What Would It Look Like? #shorts #kurzgesagt',
#     'description': "Walking around the Minecraft server might be fun, but sadly, the same couldn't be said about the Minecraft Earth... #inanutshell ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/LNv4y3wPQA0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/LNv4y3wPQA0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/LNv4y3wPQA0/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kurzgesagt – In a Nutshell',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-06-01T14:00:11Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'DYCkz7XXPT-IQ7Bau_M7fw485sA',
#    'id': {'kind': 'youtube#video', 'videoId': 'hvmIZAvt3jE'},
#    'snippet': {'publishedAt': '2023-05-25T14:00:28Z',
#     'channelId': 'UCsXVk37bltHxD1rDPwtNM8Q',
#     'title': 'How to Cut a Sandwich Perfectly – With Science #shorts #kurzgesagt',
#     'description': "There is perfect way to cut a three ingredient sandwich. ANY three ingredient sandwich. And there's also a perfect way to cut a ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/hvmIZAvt3jE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/hvmIZAvt3jE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/hvmIZAvt3jE/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kurzgesagt – In a Nutshell',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-05-25T14:00:28Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'FAwoqI0s0c4_7mThhaspT1k8CLo',
#    'id': {'kind': 'youtube#video', 'videoId': 'IayvE_jFgrc'},
#    'snippet': {'publishedAt': '2023-05-18T14:00:20Z',
#     'channelId': 'UCsXVk37bltHxD1rDPwtNM8Q',
#     'title': 'Magnetic Pole Shift - A Doomsday Scenario? #shorts #kurzgesagt',
#     'description': "Follow us for more sciencey content. Sources & further reading: https://sites.google.com/view/kgs-tiktok-sources Earth's magnetic ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/IayvE_jFgrc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/IayvE_jFgrc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/IayvE_jFgrc/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kurzgesagt – In a Nutshell',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-05-18T14:00:20Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'LMfBE7f4N_79yp2CjSGeZn8nnKc',
#    'id': {'kind': 'youtube#video', 'videoId': 'o2afhMs0aUg'},
#    'snippet': {'publishedAt': '2023-05-14T14:00:26Z',
#     'channelId': 'UCsXVk37bltHxD1rDPwtNM8Q',
#     'title': 'The Ultimate Fight: Tardigrade vs. Bird #shorts #kurzgesagt',
#     'description': 'Follow us for more sciencey content. Sources & further reading: https://sites.google.com/view/kgs-tiktok-sources Tardigrades win ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/o2afhMs0aUg/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/o2afhMs0aUg/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/o2afhMs0aUg/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kurzgesagt – In a Nutshell',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-05-14T14:00:26Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'gi-MJV9DJuTP7C_YIIoe0GDizjc',
#    'id': {'kind': 'youtube#video', 'videoId': 'UKOxj8oP59w'},
#    'snippet': {'publishedAt': '2023-05-11T14:00:15Z',
#     'channelId': 'UCsXVk37bltHxD1rDPwtNM8Q',
#     'title': 'How Tiny Can a Black Hole Be? #shorts #kurzgesagt',
#     'description': 'Follow us for more sciencey content. Sources & further reading: https://sites.google.com/view/kgs-tiktok-sources You might think a ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/UKOxj8oP59w/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/UKOxj8oP59w/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/UKOxj8oP59w/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kurzgesagt – In a Nutshell',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-05-11T14:00:15Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'TC0W5VGb7Oo_xeT9Ovxx7MfKzQ8',
#    'id': {'kind': 'youtube#video', 'videoId': 'zFhYJRqz_xk'},
#    'snippet': {'publishedAt': '2023-05-09T14:00:42Z',
#     'channelId': 'UCsXVk37bltHxD1rDPwtNM8Q',
#     'title': 'Your Body Killed Cancer 5 Minutes Ago',
#     'description': 'Sources & further reading: https://sites.google.com/view/sources-cancervsimmune/ This video was partially financed by Gates ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/zFhYJRqz_xk/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/zFhYJRqz_xk/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/zFhYJRqz_xk/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kurzgesagt – In a Nutshell',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-05-09T14:00:42Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '4cdXuK5T0pPQjdDlcThfbrsm74c',
#    'id': {'kind': 'youtube#video', 'videoId': 'pb9g6osg2aY'},
#    'snippet': {'publishedAt': '2023-05-04T16:27:19Z',
#     'channelId': 'UCsXVk37bltHxD1rDPwtNM8Q',
#     'title': 'Why Is the Ocean Salty and Rivers Are Not? #shorts #kurzgesagt',
#     'description': 'Follow us for more sciencey content. Sources & further reading: https://sites.google.com/view/kgs-tiktok-sources Understanding ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/pb9g6osg2aY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/pb9g6osg2aY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/pb9g6osg2aY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kurzgesagt – In a Nutshell',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-05-04T16:27:19Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'XUxxmaQEwQG8q-tBCCCQpsHKWC4',
#    'id': {'kind': 'youtube#video', 'videoId': 'GDSf2h9_39I'},
#    'snippet': {'publishedAt': '2023-04-11T14:00:45Z',
#     'channelId': 'UCsXVk37bltHxD1rDPwtNM8Q',
#     'title': 'Why Aliens Might Already Be On Their Way To Us',
#     'description': 'Be a part of our first Limited Drop, which honors our Cosmic Pioneers and their noble expeditions: https://kgs.link/limited-drop.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/GDSf2h9_39I/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/GDSf2h9_39I/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/GDSf2h9_39I/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kurzgesagt – In a Nutshell',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-04-11T14:00:45Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '1MLdJJLnBr4vFb6BVpVEz9qIa1Y',
#    'id': {'kind': 'youtube#video', 'videoId': '1x-i9z617z4'},
#    'snippet': {'publishedAt': '2023-03-28T14:00:05Z',
#     'channelId': 'UCsXVk37bltHxD1rDPwtNM8Q',
#     'title': 'How We Make Money on YouTube with 20M Subs',
#     'description': 'Check out some of our favorite shop products here: https://kgs.link/shop-175. Our shop is not only our most important source of ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/1x-i9z617z4/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/1x-i9z617z4/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/1x-i9z617z4/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kurzgesagt – In a Nutshell',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-03-28T14:00:05Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'KC-GJZziEKImXBwlXy8CQVUzo0A',
#    'id': {'kind': 'youtube#video', 'videoId': 'M-K7mxdN62M'},
#    'snippet': {'publishedAt': '2023-02-28T14:59:23Z',
#     'channelId': 'UCsXVk37bltHxD1rDPwtNM8Q',
#     'title': 'What Actually Happens When You Are Sick?',
#     'description': 'Offset your carbon footprint on Wren: \u200bhttps://www.wren.co/kurzgesagt. For the first 200 people who sign up, Kurzgesagt will pay ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/M-K7mxdN62M/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/M-K7mxdN62M/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/M-K7mxdN62M/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kurzgesagt – In a Nutshell',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-02-28T14:59:23Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'K2vu-_4UXYojwqoj_qRfH2wJBnU',
#    'id': {'kind': 'youtube#video', 'videoId': 'TYPFenJQciw'},
#    'snippet': {'publishedAt': '2023-02-14T14:59:37Z',
#     'channelId': 'UCsXVk37bltHxD1rDPwtNM8Q',
#     'title': 'The Most Complex Language in the World',
#     'description': "Go 'beyond the nutshell' at https://brilliant.org/nutshell/ and dive deeper into these topics and more with a free 30-day trial!",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/TYPFenJQciw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/TYPFenJQciw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/TYPFenJQciw/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kurzgesagt – In a Nutshell',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-02-14T14:59:37Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'ecjMzTzvaAVif_WUSDLiJPCpKVA',
#    'id': {'kind': 'youtube#video', 'videoId': 'aeWyp2vXxqA'},
#    'snippet': {'publishedAt': '2022-12-15T15:00:12Z',
#     'channelId': 'UCsXVk37bltHxD1rDPwtNM8Q',
#     'title': 'Black Hole Star – The Star That Shouldn&#39;t Exist',
#     'description': 'https://kgs.link/shop-172 You want to learn more about science? Check out our sciency products on the kurzgesagt shop – all ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/aeWyp2vXxqA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/aeWyp2vXxqA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/aeWyp2vXxqA/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kurzgesagt – In a Nutshell',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-12-15T15:00:12Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'e1lQ89ePS4Odi9fDNNc66G8Di3I',
#    'id': {'kind': 'youtube#video', 'videoId': 'HpcTJW4ur54'},
#    'snippet': {'publishedAt': '2022-12-11T15:00:09Z',
#     'channelId': 'UCsXVk37bltHxD1rDPwtNM8Q',
#     'title': 'How To Terraform Mars - WITH LASERS',
#     'description': "Go 'beyond the nutshell' at https://brilliant.org/nutshell by diving deeper into these topics and more with 20% off an annual ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/HpcTJW4ur54/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/HpcTJW4ur54/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/HpcTJW4ur54/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kurzgesagt – In a Nutshell',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-12-11T15:00:09Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'jov1fhjFxlEAGHsBCK8M5P0M5o4',
#    'id': {'kind': 'youtube#video', 'videoId': 'Qsbe1pD8ocE'},
#    'snippet': {'publishedAt': '2022-12-06T15:52:00Z',
#     'channelId': 'UCsXVk37bltHxD1rDPwtNM8Q',
#     'title': 'The Horror of the Slaver Ant',
#     'description': 'Offset your carbon footprint on Wren: \u200bhttps://www.wren.co/kurzgesagt. For the first 200 people who sign up, Kurzgesagt will pay ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Qsbe1pD8ocE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Qsbe1pD8ocE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Qsbe1pD8ocE/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kurzgesagt – In a Nutshell',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-12-06T15:52:00Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'G95IJSwMuQHimUVOvNTb1dkjYZ8',
#    'id': {'kind': 'youtube#video', 'videoId': 'q4DF3j4saCE'},
#    'snippet': {'publishedAt': '2022-11-23T15:00:13Z',
#     'channelId': 'UCsXVk37bltHxD1rDPwtNM8Q',
#     'title': 'The Most Extreme Explosion in the Universe',
#     'description': "Go 'beyond the nutshell' at https://brilliant.org/nutshell by diving deeper into these topics and more with 20% off an annual ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/q4DF3j4saCE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/q4DF3j4saCE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/q4DF3j4saCE/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kurzgesagt – In a Nutshell',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-11-23T15:00:13Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'mF1YmcrB7C2Hfm3oMo7zaQE1Llo',
#    'id': {'kind': 'youtube#video', 'videoId': 'Us2Z-WC9rao'},
#    'snippet': {'publishedAt': '2022-11-08T14:59:18Z',
#     'channelId': 'UCsXVk37bltHxD1rDPwtNM8Q',
#     'title': 'Why Don&#39;t We Shoot Nuclear Waste Into Space?',
#     'description': 'The new 12023 Human Era Calendar is here! https://kgs.link/calendar WORLDWIDE SHIPPING AVAILABLE. This time you can ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Us2Z-WC9rao/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Us2Z-WC9rao/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Us2Z-WC9rao/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kurzgesagt – In a Nutshell',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-11-08T14:59:18Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'Y_sYGSXdIw8m9BbezOI_ePTAroY',
#    'id': {'kind': 'youtube#video', 'videoId': 'fXb02MQ78yQ'},
#    'snippet': {'publishedAt': '2022-10-18T13:59:41Z',
#     'channelId': 'UCsXVk37bltHxD1rDPwtNM8Q',
#     'title': 'What Happens if a Supervolcano Blows Up?',
#     'description': "Go 'beyond the nutshell' at https://brilliant.org/nutshell by diving deeper into these topics and more with 20% off an annual ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/fXb02MQ78yQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/fXb02MQ78yQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/fXb02MQ78yQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kurzgesagt – In a Nutshell',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-10-18T13:59:41Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'yl20979OTXvD-EcUlAHPoU54dnY',
#    'id': {'kind': 'youtube#video', 'videoId': 'FfWtIaDtfYk'},
#    'snippet': {'publishedAt': '2022-10-04T14:00:33Z',
#     'channelId': 'UCsXVk37bltHxD1rDPwtNM8Q',
#     'title': 'Let’s Travel to The Most Extreme Place in The Universe',
#     'description': 'The new 12023 Human Era Calendar is here! https://kgs.link/calendar WORLDWIDE SHIPPING AVAILABLE. This time you can ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/FfWtIaDtfYk/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/FfWtIaDtfYk/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/FfWtIaDtfYk/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kurzgesagt – In a Nutshell',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-10-04T14:00:33Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'aLRimwHqq8VItOCqu0BgzeOT5pQ',
#    'id': {'kind': 'youtube#video', 'videoId': 'I9hJ_Rux9y0'},
#    'snippet': {'publishedAt': '2022-09-06T13:59:36Z',
#     'channelId': 'UCsXVk37bltHxD1rDPwtNM8Q',
#     'title': 'Why You Are Lonely and How to Make Friends',
#     'description': "We want to be part of your friendship journey, so we've created a few things you can share with new and old friends: ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/I9hJ_Rux9y0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/I9hJ_Rux9y0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/I9hJ_Rux9y0/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kurzgesagt – In a Nutshell',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-09-06T13:59:36Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'crZf3dVEr_FYowZL0v0Dj39GpOk',
#    'id': {'kind': 'youtube#video', 'videoId': 'W93XyXHI8Nw'},
#    'snippet': {'publishedAt': '2022-08-16T13:59:34Z',
#     'channelId': 'UCsXVk37bltHxD1rDPwtNM8Q',
#     'title': 'Is Civilization on the Brink of Collapse?',
#     'description': 'What We Owe The Future is available now — you can get it wherever you get your (audio)books or here: ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/W93XyXHI8Nw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/W93XyXHI8Nw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/W93XyXHI8Nw/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kurzgesagt – In a Nutshell',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-08-16T13:59:34Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'hDqboian2jDqs-kwXDNtAgSe7aU',
#    'id': {'kind': 'youtube#video', 'videoId': '4u5I8GYB79Y'},
#    'snippet': {'publishedAt': '2022-07-26T13:58:55Z',
#     'channelId': 'UCsXVk37bltHxD1rDPwtNM8Q',
#     'title': 'The Deadliest Virus on Earth',
#     'description': "Go 'beyond the nutshell' at https://brilliant.org/nutshell by diving deeper into these topics and more with 20% off an annual ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/4u5I8GYB79Y/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/4u5I8GYB79Y/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/4u5I8GYB79Y/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kurzgesagt – In a Nutshell',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-07-26T13:58:55Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'J8I1Lc9RozFQoMHxkDTO0YCYQDI',
#    'id': {'kind': 'youtube#video', 'videoId': 'LEENEFaVUzU'},
#    'snippet': {'publishedAt': '2022-06-28T14:00:23Z',
#     'channelId': 'UCsXVk37bltHxD1rDPwtNM8Q',
#     'title': 'The Last Human – A Glimpse Into The Far Future',
#     'description': 'Because of the potential size of the future, the most important thing about our actions today might be their impact on future ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/LEENEFaVUzU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/LEENEFaVUzU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/LEENEFaVUzU/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kurzgesagt – In a Nutshell',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-06-28T14:00:23Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'D35306JmV5oFmRRFmYhXxgQHwGo',
#    'id': {'kind': 'youtube#video', 'videoId': '75d_29QWELk'},
#    'snippet': {'publishedAt': '2022-06-07T14:00:05Z',
#     'channelId': 'UCsXVk37bltHxD1rDPwtNM8Q',
#     'title': 'Change Your Life – One Tiny Step at a Time',
#     'description': 'Change Your Life – One Tiny Step at a Time Get your Habit Journal here: https://kgs.link/shop-162 Sources & further reading: ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/75d_29QWELk/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/75d_29QWELk/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/75d_29QWELk/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kurzgesagt – In a Nutshell',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-06-07T14:00:05Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'cKf_OhxC0Dmnr3Tor529-o_d0Is',
#    'id': {'kind': 'youtube#video', 'videoId': 'Pj-h6MEgE7I'},
#    'snippet': {'publishedAt': '2022-05-17T13:59:44Z',
#     'channelId': 'UCsXVk37bltHxD1rDPwtNM8Q',
#     'title': 'You Are Not Where You Think You Are',
#     'description': 'Getting something from the kurzgesagt shop is the best way to support us and to keep our videos free for everyone.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Pj-h6MEgE7I/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Pj-h6MEgE7I/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Pj-h6MEgE7I/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kurzgesagt – In a Nutshell',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-05-17T13:59:44Z'}}]}

# %%
response["items"][0]['id']['videoId']
# Out:
# 'nGggU-Cxhv0'

# %%
response["items"][0]['snippet']['title']
# Out:
# 'Your Tattoo is INSIDE Your Immune System. Literally'

# %%
response["items"][0]['snippet']['publishedAt']
# Out:
# '2023-12-12T15:00:01Z'

# %%
upload_time = response["items"][0]['snippet']['publishedAt']
upload_time = str(upload_time).split("T")[0]
upload_time
# Out:
# '2023-12-12'

# %%
video_title = response["items"][0]['snippet']['title']
video_id = response["items"][0]['id']['videoId']
upload_time = response["items"][0]['snippet']['publishedAt']
upload_time = str(upload_time).split("T")[0]
print("upload time: " + upload_time)
print("video id: " + video_id)
print("video title: " + video_title)
# Out:
# upload time: 2023-12-12
# video id: nGggU-Cxhv0
# video title: Your Tattoo is INSIDE Your Immune System. Literally

# %%
# for loop in response 
for video in response["items"]:
    video_title = video['snippet']['title']
    print(video_title)
# Out:
# Your Tattoo is INSIDE Your Immune System. Literally
# How To Destroy The Universe
# The Moment Kurzgesagt Changed Forever
# The Internet is Worse Than Ever – Now What?
# The Last Thing To Ever Happen In The Universe
# How to Win an Interstellar War
# 4.5 Billion Years in 1 Hour
# A Glimpse Into Our Future
# Ancient Life as Old as the Universe
# Why Korea is Dying Out
# We Did The Math - You Are Dead!
# How A Nuclear War Will Start - Minute by Minute
# What Happens If You Destroy A Black Hole?
# The (Second) Deadliest Virus
# How Many Moons Could Earth Handle? #kurzgesagt #shorts
# What If You’re in Space without a Spacesuit? #kurzgesagt #shorts
# What Happens if Earth Suddenly Stops Rotating? #kurzgesagt #shorts
# Earth&#39;s Hidden Gem: The Astonishing Diversity of Fauna and Flora #shorts #kurzgesagt
# The Most Dangerous Weapon Is Not Nuclear
# The Next Atomic Bomb Is Made of DNA #kurzgesagt #shorts
# Are Your Friends More Popular than You? #shorts #kurzgesagt
# Let&#39;s Make Earth Twice as Large! #shorts #kurzgesagt
# The Reason Why Cancer is so Hard to Beat
# Why Does Humanity Exist NOW? #shorts #kurzgesagt
# The Black Hole That Kills Galaxies - Quasars
# How do Lasers Work? #shorts #kurzgesagt
# Earth as a Cube – What Would It Look Like? #shorts #kurzgesagt
# How to Cut a Sandwich Perfectly – With Science #shorts #kurzgesagt
# Magnetic Pole Shift - A Doomsday Scenario? #shorts #kurzgesagt
# The Ultimate Fight: Tardigrade vs. Bird #shorts #kurzgesagt
# How Tiny Can a Black Hole Be? #shorts #kurzgesagt
# Your Body Killed Cancer 5 Minutes Ago
# Why Is the Ocean Salty and Rivers Are Not? #shorts #kurzgesagt
# Why Aliens Might Already Be On Their Way To Us
# How We Make Money on YouTube with 20M Subs
# What Actually Happens When You Are Sick?
# The Most Complex Language in the World
# Black Hole Star – The Star That Shouldn&#39;t Exist
# How To Terraform Mars - WITH LASERS
# The Horror of the Slaver Ant
# The Most Extreme Explosion in the Universe
# Why Don&#39;t We Shoot Nuclear Waste Into Space?
# What Happens if a Supervolcano Blows Up?
# Let’s Travel to The Most Extreme Place in The Universe
# Why You Are Lonely and How to Make Friends
# Is Civilization on the Brink of Collapse?
# The Deadliest Virus on Earth
# The Last Human – A Glimpse Into The Far Future
# Change Your Life – One Tiny Step at a Time
# You Are Not Where You Think You Are

# %%
for video in response["items"]:
    if video['id']['kind'] == "youtube#video":
        video_title = video['snippet']['title']
        print(video_title)
# Out:
# Your Tattoo is INSIDE Your Immune System. Literally
# How To Destroy The Universe
# The Moment Kurzgesagt Changed Forever
# The Internet is Worse Than Ever – Now What?
# The Last Thing To Ever Happen In The Universe
# How to Win an Interstellar War
# 4.5 Billion Years in 1 Hour
# A Glimpse Into Our Future
# Ancient Life as Old as the Universe
# Why Korea is Dying Out
# We Did The Math - You Are Dead!
# How A Nuclear War Will Start - Minute by Minute
# What Happens If You Destroy A Black Hole?
# The (Second) Deadliest Virus
# How Many Moons Could Earth Handle? #kurzgesagt #shorts
# What If You’re in Space without a Spacesuit? #kurzgesagt #shorts
# What Happens if Earth Suddenly Stops Rotating? #kurzgesagt #shorts
# Earth&#39;s Hidden Gem: The Astonishing Diversity of Fauna and Flora #shorts #kurzgesagt
# The Most Dangerous Weapon Is Not Nuclear
# The Next Atomic Bomb Is Made of DNA #kurzgesagt #shorts
# Are Your Friends More Popular than You? #shorts #kurzgesagt
# Let&#39;s Make Earth Twice as Large! #shorts #kurzgesagt
# The Reason Why Cancer is so Hard to Beat
# Why Does Humanity Exist NOW? #shorts #kurzgesagt
# The Black Hole That Kills Galaxies - Quasars
# How do Lasers Work? #shorts #kurzgesagt
# Earth as a Cube – What Would It Look Like? #shorts #kurzgesagt
# How to Cut a Sandwich Perfectly – With Science #shorts #kurzgesagt
# Magnetic Pole Shift - A Doomsday Scenario? #shorts #kurzgesagt
# The Ultimate Fight: Tardigrade vs. Bird #shorts #kurzgesagt
# How Tiny Can a Black Hole Be? #shorts #kurzgesagt
# Your Body Killed Cancer 5 Minutes Ago
# Why Is the Ocean Salty and Rivers Are Not? #shorts #kurzgesagt
# Why Aliens Might Already Be On Their Way To Us
# How We Make Money on YouTube with 20M Subs
# What Actually Happens When You Are Sick?
# The Most Complex Language in the World
# Black Hole Star – The Star That Shouldn&#39;t Exist
# How To Terraform Mars - WITH LASERS
# The Horror of the Slaver Ant
# The Most Extreme Explosion in the Universe
# Why Don&#39;t We Shoot Nuclear Waste Into Space?
# What Happens if a Supervolcano Blows Up?
# Let’s Travel to The Most Extreme Place in The Universe
# Why You Are Lonely and How to Make Friends
# Is Civilization on the Brink of Collapse?
# The Deadliest Virus on Earth
# The Last Human – A Glimpse Into The Far Future
# Change Your Life – One Tiny Step at a Time
# You Are Not Where You Think You Are

# %%
video_url_endpoint = "https://www.googleapis.com/youtube/v3/videos?id="+video_id+"&part=statistics&key="+YOUTUBE_API_KEY
video_id = "nGggU-Cxhv0"
video_response = requests.get(video_url_endpoint).json()

# %%
video_response
# Out:
# {'kind': 'youtube#videoListResponse',
#  'etag': 'EvWdV3tTIUlDuw1zS4ohsWhaB9A',
#  'items': [{'kind': 'youtube#video',
#    'etag': 'usgigCatsJ7tSg6t8lj1V60wpio',
#    'id': 'nGggU-Cxhv0',
#    'statistics': {'viewCount': '5642531',
#     'likeCount': '241426',
#     'favoriteCount': '0',
#     'commentCount': '8829'}}],
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 1}}

# %%
video_response["items"][0]["statistics"]
# Out:
# {'viewCount': '5642531',
#  'likeCount': '241426',
#  'favoriteCount': '0',
#  'commentCount': '8829'}

# %% [markdown]
# # Creating Workflow

# %%
import pandas as pd

# %%
df = pd.DataFrame(columns=["video_id","video_title","upload_date","view_count","like_count"]) 

for video in response['items']:
    if video['id']['kind'] == 'youtube#video':
        video_title = video['snippet']['title']
        video_id = video['id']['videoId']
        upload_date = video['snippet']['publishedAt']
        upload_date= str(upload_date).split("T")[0]

        # collecting video statistics
        video_stats_url = "https://www.googleapis.com/youtube/v3/videos?id="+video_id+"&part=statistics&key="+YOUTUBE_API_KEY
        video_stats_response = requests.get(video_stats_url).json()

        view_count = video_stats_response['items'][0]["statistics"]["viewCount"]
        like_count = video_stats_response['items'][0]["statistics"]["likeCount"]

        #save in pandas df
        df = df.append_({
            "video_id": video_id,
            "video_title": video_title,
            "upload_date": upload_date,
            "view_count": view_count,
            "like_count": like_count
        }, 
        ignore_index = True
        )
return df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9796\1712329001.py in ?()
#      14         view_count = video_stats_response['items'][0]["statistics"]["viewCount"]
#      15         like_count = video_stats_response['items'][0]["statistics"]["likeCount"]
#      16
#      17         #save in pandas df
# ---> 18         df = df.append_({
#      19             "video_id": video_id,
#      20             "video_title": video_title,
#      21             "upload_date": upload_date,
#
# c:\Users\GECE\anaconda3\envs\Lovelace\lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append_'

# %%
import pandas as pd

df = pd.DataFrame(columns=["video_id", "video_title", "upload_date", "view_count", "like_count"])

for video in response['items']:
    if video['id']['kind'] == 'youtube#video':
        video_title = video['snippet']['title']
        video_id = video['id']['videoId']
        upload_date = video['snippet']['publishedAt']
        upload_date = str(upload_date).split("T")[0]

        # collecting video statistics
        video_stats_url = "https://www.googleapis.com/youtube/v3/videos?id="+video_id+"&part=statistics&key="+YOUTUBE_API_KEY
        video_stats_response = requests.get(video_stats_url).json()

        view_count = video_stats_response['items'][0]["statistics"]["viewCount"]
        like_count = video_stats_response['items'][0]["statistics"]["likeCount"]

        # save in pandas df
        new_row = {
            "video_id": video_id,
            "video_title": video_title,
            "upload_date": upload_date,
            "view_count": view_count,
            "like_count": like_count
        }
        df = pd.concat([df, pd.DataFrame([new_row])], ignore_index=True)

print(df)
# Out:
#        video_id                                        video_title  \
# 0   nGggU-Cxhv0  Your Tattoo is INSIDE Your Immune System. Lite...
# 1   HR2C_7G_yRQ                        How To Destroy The Universe
# 2   yDMZJ7LgrGY              The Moment Kurzgesagt Changed Forever
# 3   fuFlMtZmvY0        The Internet is Worse Than Ever – Now What?
# 4   FgnjdW-x7mQ      The Last Thing To Ever Happen In The Universe
# 5   tybKnGZRwcU                     How to Win an Interstellar War
# 6   S7TUe5w6RHo                        4.5 Billion Years in 1 Hour
# 7   Qtmrp_4BKRQ                          A Glimpse Into Our Future
# 8   JOiGEI9pQBs                Ancient Life as Old as the Universe
# 9   LBudghsdByQ                             Why Korea is Dying Out
# 10  4Stzj2_Rlo4                    We Did The Math - You Are Dead!
# 11  wmP3MBjsx20    How A Nuclear War Will Start - Minute by Minute
# 12  cFslUSyfZPc          What Happens If You Destroy A Black Hole?
# 13  Kr57ax0OWMk                       The (Second) Deadliest Virus
# 14  28T91fgkpkA  How Many Moons Could Earth Handle? #kurzgesagt...
# 15  4TlyzKBm5yw  What If You’re in Space without a Spacesuit? #...
# 16  kblSnj0p6bE  What Happens if Earth Suddenly Stops Rotating?...
# 17  FPKRFw2jrnU  Earth&#39;s Hidden Gem: The Astonishing Divers...
# 18  9FppammO1zk           The Most Dangerous Weapon Is Not Nuclear
# 19  8Ey3_9N089k  The Next Atomic Bomb Is Made of DNA #kurzgesag...
# 20  _arb8Fu3LXo  Are Your Friends More Popular than You? #short...
# 21  XFM4tCakAXY  Let&#39;s Make Earth Twice as Large! #shorts #...
# 22  uoJwt9l-XhQ           The Reason Why Cancer is so Hard to Beat
# 23  BNvL_uZhTsY   Why Does Humanity Exist NOW? #shorts #kurzgesagt
# 24  V4Z8EdiJxgk       The Black Hole That Kills Galaxies - Quasars
# 25  RzwaiFvyN6s            How do Lasers Work? #shorts #kurzgesagt
# 26  LNv4y3wPQA0  Earth as a Cube – What Would It Look Like? #sh...
# 27  hvmIZAvt3jE  How to Cut a Sandwich Perfectly – With Science...
# 28  IayvE_jFgrc  Magnetic Pole Shift - A Doomsday Scenario? #sh...
# 29  o2afhMs0aUg  The Ultimate Fight: Tardigrade vs. Bird #short...
# 30  UKOxj8oP59w  How Tiny Can a Black Hole Be? #shorts #kurzgesagt
# 31  zFhYJRqz_xk              Your Body Killed Cancer 5 Minutes Ago
# 32  pb9g6osg2aY  Why Is the Ocean Salty and Rivers Are Not? #sh...
# 33  GDSf2h9_39I     Why Aliens Might Already Be On Their Way To Us
# 34  1x-i9z617z4         How We Make Money on YouTube with 20M Subs
# 35  M-K7mxdN62M           What Actually Happens When You Are Sick?
# 36  TYPFenJQciw             The Most Complex Language in the World
# 37  aeWyp2vXxqA  Black Hole Star – The Star That Shouldn&#39;t ...
# 38  HpcTJW4ur54                How To Terraform Mars - WITH LASERS
# 39  Qsbe1pD8ocE                       The Horror of the Slaver Ant
# 40  q4DF3j4saCE         The Most Extreme Explosion in the Universe
# 41  Us2Z-WC9rao   Why Don&#39;t We Shoot Nuclear Waste Into Space?
# 42  fXb02MQ78yQ           What Happens if a Supervolcano Blows Up?
# 43  FfWtIaDtfYk  Let’s Travel to The Most Extreme Place in The ...
# 44  I9hJ_Rux9y0         Why You Are Lonely and How to Make Friends
# 45  W93XyXHI8Nw          Is Civilization on the Brink of Collapse?
# 46  4u5I8GYB79Y                       The Deadliest Virus on Earth
# 47  LEENEFaVUzU     The Last Human – A Glimpse Into The Far Future
# 48  75d_29QWELk         Change Your Life – One Tiny Step at a Time
# 49  Pj-h6MEgE7I                You Are Not Where You Think You Are
#
#    upload_date view_count like_count
# 0   2023-12-12    5644404     241487
# 1   2023-12-08    3245818     165761
# 2   2023-12-05    1582748     109733
# 3   2023-11-29    5755156     345528
# 4   2023-11-21    4193341     213452
# 5   2023-11-15    4833217     221741
# 6   2023-11-10    6742362     463060
# 7   2023-10-17    1534106      54695
# 8   2023-10-10    5172634     241078
# 9   2023-10-04    7395653     293550
# 10  2023-09-12    5929120     295806
# 11  2023-08-22    6179616     280404
# 12  2023-08-16    7348712     287018
# 13  2023-08-08    4585051     190840
# 14  2023-07-27    5130870     378186
# 15  2023-07-20    2556006     181674
# 16  2023-07-13    2862049     226464
# 17  2023-07-06     920487      67733
# 18  2023-07-02    4556049     200089
# 19  2023-07-02    2000485     132030
# 20  2023-06-29    1905640     146597
# 21  2023-06-22    5464354     397199
# 22  2023-06-18    5252700     224811
# 23  2023-06-15    2580688     229711
# 24  2023-06-11    7101601     246115
# 25  2023-06-08    5462955     413170
# 26  2023-06-01    8491996     544949
# 27  2023-05-25    7500869     440303
# 28  2023-05-18    4795548     347867
# 29  2023-05-14    3285974     211381
# 30  2023-05-11    5887491     424675
# 31  2023-05-09    6229987     272705
# 32  2023-05-04    5304316     420326
# 33  2023-04-11    7499229     274831
# 34  2023-03-28    4161527     323737
# 35  2023-02-28    5602043     229402
# 36  2023-02-14    5426405     259399
# 37  2022-12-15    9769849     376443
# 38  2022-12-11    6974138     260764
# 39  2022-12-06    7419382     299405
# 40  2022-11-23    7845529     252016
# 41  2022-11-08    9476410     393017
# 42  2022-10-18    8239481     280322
# 43  2022-10-04   11271431     508578
# 44  2022-09-06    5976789     312352
# 45  2022-08-16    9528851     380754
# 46  2022-07-26   13288504     415714
# 47  2022-06-28   11380763     497334
# 48  2022-06-07    9859363     574468
# 49  2022-05-17    8918050     387920
